# %% [markdown]
# # IRS Data

# %%
import duckdb

duck = duckdb.connect()

# %%
duck.execute("create or replace table raw_fl_cd AS SELECT * FROM read_xlsx('https://www.irs.gov/pub/irs-soi/22incdfl.xlsx', range='A4:FG', all_varchar=true, header=true);")

duck.execute("show table raw_fl_cd").df()
# Out:
#                                            column_name column_type null   key  \
# 0                          Congressional\ndistrict [1]     VARCHAR  YES  None
# 1    Size of adjusted gross income by congressional...     VARCHAR  YES  None
# 2                                Number of returns [2]     VARCHAR  YES  None
# 3                             Number of single returns     VARCHAR  YES  None
# 4                              Number of joint returns     VARCHAR  YES  None
# ..                                                 ...         ...  ...   ...
# 158                                                _72     VARCHAR  YES  None
# 159                         Overpayments refunded [16]     VARCHAR  YES  None
# 160                                                _73     VARCHAR  YES  None
# 161              Credited to next year's estimated tax     VARCHAR  YES  None
# 162                                                _74     VARCHAR  YES  None
#
#     default extra
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# ..      ...   ...
# 158    None  None
# 159    None  None
# 160    None  None
# 161    None  None
# 162    None  None
#
# [163 rows x 6 columns]

# %%
duck.sql("""
WITH brackets AS (
    PIVOT (
        SELECT 
            "Congressional\ndistrict [1]" AS district,
            "Size of adjusted gross income by congressional district" AS income_bracket,
            -- Remove commas and cast to numeric to allow math operations
            CAST(REPLACE("Number of returns [2]", ',', '') AS DOUBLE) AS return_count
        FROM raw_fl_cd
        WHERE try("Congressional\ndistrict [1]"::int) BETWEEN 1 AND 999
    )
    ON income_bracket
    USING FIRST(return_count)
    GROUP BY district
)
SELECT 
    *, 
    ("$500,000 or more" / "$100,000 under $200,000") AS richness_ratio
FROM brackets
ORDER BY richness_ratio DESC;
""").df()
# Out:
#    district  $1 under $10,000  $10,000 under $25,000  $100,000 under $200,000  \
# 0        27           44560.0                74960.0                  49020.0
# 1        22           41050.0                69820.0                  63050.0
# 2        19           37670.0                69620.0                  72010.0
# 3        21           42550.0                76960.0                  60730.0
# 4        18           39430.0                70900.0                  70430.0
# 5        23           40700.0                70810.0                  61610.0
# 6        14           39530.0                76950.0                  51860.0
# 7        24           47150.0               111000.0                  27120.0
# 8        16           41700.0                74150.0                  82250.0
# 9        13           35300.0                64230.0                  52600.0
# 10       10           44970.0                98220.0                  49170.0
# 11        7           36030.0                69810.0                  58450.0
# 12        4           37080.0                62050.0                  90700.0
# 13       25           49640.0               100810.0                  43440.0
# 14        8           38700.0                69480.0                  68110.0
# 15        1           36150.0                67940.0                  62980.0
# 16       17           38390.0                69750.0                  58830.0
# 17       26           47280.0               101940.0                  44970.0
# 18        6           41930.0                77470.0                  59170.0
# 19       12           40050.0                69180.0                  67720.0
# 20        3           33770.0                65600.0                  50890.0
# 21        2           33200.0                61430.0                  48980.0
# 22       20           42840.0               104800.0                  33690.0
